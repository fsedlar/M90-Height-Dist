# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

agg = pd.read_csv("cz_10k_agg.csv")
agg.head(50)


GU = agg.iloc[0:14,14]
INS = agg.iloc[0:14,32]
period = agg.iloc[0:14,1]

for i in range(3, 14):
    plt.plot(agg.iloc[0:14,i], period, label=i)

    
plt.legend()
plt.show()

##plt.plot(GU, period)
##plt.plot(INS, period)
##plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

agg = pd.read_csv("cz_10k_agg.csv")
agg.head(50)
# Out:
#       AREA  ReturnPeriod    AGG_RES_GU  AGG_RES_BLDG_GU  AGG_RES_CONT_GU  \
# 0       CZ             0  2.240522e+08     1.434531e+08     8.059912e+07
# 1       CZ             2  1.048533e+08     6.727035e+07     3.754872e+07
# 2       CZ             5  3.232730e+08     2.071523e+08     1.165495e+08
# 3       CZ            10  5.558216e+08     3.542385e+08     2.007548e+08
# 4       CZ            20  8.221486e+08     5.262091e+08     2.962712e+08
# 5       CZ            40  1.155550e+09     7.426387e+08     4.201581e+08
# 6       CZ            50  1.308217e+09     8.435826e+08     4.711311e+08
# 7       CZ           100  1.746464e+09     1.111363e+09     6.287508e+08
# 8       CZ           250  2.383001e+09     1.527609e+09     8.603251e+08
# 9       CZ           500  2.906615e+09     1.882919e+09     1.019230e+09
# 10      CZ          1000  3.487608e+09     2.270381e+09     1.216669e+09
# 11      CZ          2500  4.057962e+09     2.600283e+09     1.457679e+09
# ...
