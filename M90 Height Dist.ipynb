# %%
# Data from Switzerland_BuildingsByTypeByUnitsByFloorsByYearBuilt_Canton_2013
# \\edc\rs\Flood\Models\Model_090\V_02.00.0.00\AllCountries\4_Vulnerability\Exposure
# Tab 'Compile'

#NOTE - all the building counts for each floor appear to be the same

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Import csv filse from EDC
CF_Height = pd.read_csv("CF_Height.csv")
AT_Height = pd.read_csv("AT_Height.csv")
CZ_Height = pd.read_csv("CZ_Height.csv")

#Remove unnecessary columns
#CF_Height = CF_Height.loc[:,["NumberOfFloors", "BuildingCount"]]
AT_Height = AT_Height.loc[:7,:]
CZ_Height = CZ_Height.loc[:,["BuildingType", "NumberOfFloors", "BuildingCount"]]

CZ_Height.head()
# Out:
#    BuildingType NumberOfFloors  BuildingCount
# 0  SingleFamily         1Floor              4
# 1  SingleFamily        2Floors             39
# 2  SingleFamily        3Floors             40
# 3  SingleFamily        4Floors              0
# 4  SingleFamily        5Floors              0

# %%
d = {}

for x in range(1,13):
    if x ==1:
        d["CZ_Floor{0}".format(x)] = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "{}Floor".format(x)) & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))].sum() 
    elif x ==11:
        d["CZ_Floor{0}".format(x)] = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "11to12Floors".format(x)) & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))].sum() 
    elif x ==12:
        d["CZ_Floor{0}".format(x)] = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "13PlusFloors".format(x)) & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))].sum() 
    else:
        d["CZ_Floor{0}".format(x)] = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "{}Floors".format(x)) & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))].sum() 

d
# Out:
# {'CZ_Floor1': BuildingType      SingleFamilyMultiDwellingSingleFamilyMultiDwel...
#  NumberOfFloors    1Floor1Floor1Floor1Floor1Floor1Floor1Floor1Flo...
#  BuildingCount                                                587985
#  dtype: object,
#  'CZ_Floor10': BuildingType      SingleFamilyMultiDwellingSingleFamilyMultiDwel...
#  NumberOfFloors    10Floors10Floors10Floors10Floors10Floors10Floo...
#  BuildingCount                                                   700
#  dtype: object,
#  'CZ_Floor11': BuildingType      SingleFamilyMultiDwellingSingleFamilyMultiDwel...
#  NumberOfFloors    11to12Floors11to12Floors11to12Floors11to12Floo...
#  BuildingCount                                                  2108
#  dtype: object,
#  'CZ_Floor12': BuildingType      SingleFamilyMultiDwellingSingleFamilyMultiDwel...
#  NumberOfFloors    13PlusFloors13PlusFloors13PlusFloors13PlusFloo...
#  BuildingCount                                                  1552
#  dtype: object,
# ...

# %%
#Czech Republic

#LOB 1 - Single Family, Multi Dwelling
#LOB 2 - Non Res. Mixed
#LOB 6 - 

    
#LOB 1
CZ_Bld_Count_1Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "1Floor") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_1Floor_LOB1 = CZ_Bld_Count_1Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 1 Story, LOB = 1:", CZ_Bld_Count_1Floor_LOB1)

CZ_Bld_Count_2Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "2Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_2Floor_LOB1 = CZ_Bld_Count_2Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 2 Story, LOB = 1:", CZ_Bld_Count_2Floor_LOB1)

CZ_Bld_Count_3Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "3Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_3Floor_LOB1 = CZ_Bld_Count_3Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 3 Story, LOB = 1:", CZ_Bld_Count_3Floor_LOB1)

CZ_Bld_Count_4Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "4Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_4Floor_LOB1 = CZ_Bld_Count_4Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 4 Story, LOB = 1:", CZ_Bld_Count_4Floor_LOB1)

CZ_Bld_Count_5Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "5Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_5Floor_LOB1 = CZ_Bld_Count_5Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 5 Story, LOB = 1:", CZ_Bld_Count_5Floor_LOB1)

CZ_Bld_Count_6Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "6Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_6Floor_LOB1 = CZ_Bld_Count_6Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 6 Story, LOB = 1:", CZ_Bld_Count_6Floor_LOB1)

CZ_Bld_Count_7Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "7Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_7Floor_LOB1 = CZ_Bld_Count_7Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 7 Story, LOB = 1:", CZ_Bld_Count_7Floor_LOB1)

CZ_Bld_Count_8Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "8Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_8Floor_LOB1 = CZ_Bld_Count_8Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 8 Story, LOB = 1:", CZ_Bld_Count_8Floor_LOB1)

CZ_Bld_Count_9Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "9Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_9Floor_LOB1 = CZ_Bld_Count_9Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 9 Story, LOB = 1:", CZ_Bld_Count_9Floor_LOB1)

CZ_Bld_Count_10Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "10Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_10Floor_LOB1 = CZ_Bld_Count_10Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 10 Story, LOB = 1:", CZ_Bld_Count_10Floor_LOB1)

CZ_Bld_Count_11to12Floor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "11to12Floors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_11to12Floor_LOB1 = CZ_Bld_Count_11to12Floor_LOB1["BuildingCount"].sum()
print("Czech Republic 11to12 Story, LOB = 1:", CZ_Bld_Count_11to12Floor_LOB1)

CZ_Bld_Count_13PlusFloor_LOB1 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "13PlusFloors") & ((CZ_Height["BuildingType"] == "SingleFamily") | (CZ_Height["BuildingType"] == "MultiDwelling"))]
CZ_Bld_Count_13PlusFloor_LOB1 = CZ_Bld_Count_13PlusFloor_LOB1["BuildingCount"].sum()
print("Czech Republic 13Plus Story, LOB = 1:", CZ_Bld_Count_13PlusFloor_LOB1)


#LOB 2
CZ_Bld_Count_1Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "1Floor") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_1Floor_LOB2 = CZ_Bld_Count_1Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 1 Story, LOB = 2:", CZ_Bld_Count_1Floor_LOB2)

CZ_Bld_Count_2Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "2Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_2Floor_LOB2 = CZ_Bld_Count_2Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 2 Story, LOB = 2:", CZ_Bld_Count_2Floor_LOB2)

CZ_Bld_Count_3Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "3Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_3Floor_LOB2 = CZ_Bld_Count_3Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 3 Story, LOB = 2:", CZ_Bld_Count_3Floor_LOB2)

CZ_Bld_Count_4Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "4Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_4Floor_LOB2 = CZ_Bld_Count_4Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 4 Story, LOB = 2:", CZ_Bld_Count_4Floor_LOB2)

CZ_Bld_Count_5Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "5Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_5Floor_LOB2 = CZ_Bld_Count_5Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 5 Story, LOB = 2:", CZ_Bld_Count_5Floor_LOB2)

CZ_Bld_Count_6Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "6Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_6Floor_LOB2 = CZ_Bld_Count_6Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 6 Story, LOB = 2:", CZ_Bld_Count_6Floor_LOB2)

CZ_Bld_Count_7Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "7Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_7Floor_LOB2 = CZ_Bld_Count_7Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 7 Story, LOB = 2:", CZ_Bld_Count_7Floor_LOB2)

CZ_Bld_Count_8Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "8Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_8Floor_LOB2 = CZ_Bld_Count_8Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 3 Story, LOB = 8:", CZ_Bld_Count_8Floor_LOB2)

CZ_Bld_Count_9Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "9Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_9Floor_LOB2 = CZ_Bld_Count_9Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 9 Story, LOB = 2:", CZ_Bld_Count_9Floor_LOB2)

CZ_Bld_Count_10Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "10Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_10Floor_LOB2 = CZ_Bld_Count_10Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 10 Story, LOB = 2:", CZ_Bld_Count_10Floor_LOB2)

CZ_Bld_Count_11to12Floor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "11to12Floors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_11to12Floor_LOB2 = CZ_Bld_Count_11to12Floor_LOB2["BuildingCount"].sum()
print("Czech Republic 11to12 Story, LOB = 2:", CZ_Bld_Count_11to12Floor_LOB2)

CZ_Bld_Count_13PlusFloor_LOB2 = CZ_Height.loc[(CZ_Height["NumberOfFloors"] == "13PlusFloors") & ((CZ_Height["BuildingType"] == "NonResidential"))]
CZ_Bld_Count_13PlusFloor_LOB2 = CZ_Bld_Count_13PlusFloor_LOB2["BuildingCount"].sum()
print("Czech Republic 13Plus Story, LOB = 2:", CZ_Bld_Count_13PlusFloor_LOB2)







CZ_Bld_Count_2 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "2Floors"].sum()
CZ_Bld_Count_2 = CZ_Bld_Count_2["BuildingCount"]

CZ_Bld_Count_3 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "3Floors"].sum()
CZ_Bld_Count_3 = CZ_Bld_Count_3["BuildingCount"]

CZ_Bld_Count_4 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "4Floors"].sum()
CZ_Bld_Count_4 = CZ_Bld_Count_4["BuildingCount"]

CZ_Bld_Count_5 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "5Floors"].sum()
CZ_Bld_Count_5 = CZ_Bld_Count_5["BuildingCount"]

CZ_Bld_Count_6 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "6Floors"].sum()
CZ_Bld_Count_6 = CZ_Bld_Count_6["BuildingCount"]

CZ_Bld_Count_7 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "7Floors"].sum()
CZ_Bld_Count_7 = CZ_Bld_Count_7["BuildingCount"]

CZ_Bld_Count_8 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "8Floors"].sum()
CZ_Bld_Count_8 = CZ_Bld_Count_8["BuildingCount"]

CZ_Bld_Count_9 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "9Floors"].sum()
CZ_Bld_Count_9 = CZ_Bld_Count_9["BuildingCount"]

CZ_Bld_Count_10 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "10Floors"].sum()
CZ_Bld_Count_10 = CZ_Bld_Count_10["BuildingCount"]

CZ_Bld_Count_11to12 = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "11to12Floors"].sum()
CZ_Bld_Count_11to12 = CZ_Bld_Count_11to12["BuildingCount"]

CZ_Bld_Count_13Plus = CZ_Height.loc[CZ_Height["NumberOfFloors"] == "13PlusFloors"].sum()
CZ_Bld_Count_13Plus = CZ_Bld_Count_13Plus["BuildingCount"]

CZ_Total = sum([CZ_Bld_Count_1, CZ_Bld_Count_2, CZ_Bld_Count_3, CZ_Bld_Count_4, CZ_Bld_Count_5, CZ_Bld_Count_6, CZ_Bld_Count_7, CZ_Bld_Count_8, CZ_Bld_Count_9, CZ_Bld_Count_10, CZ_Bld_Count_11to12, CZ_Bld_Count_13Plus])

CZ_Low_Rise = sum([CZ_Bld_Count_1, CZ_Bld_Count_2, CZ_Bld_Count_3])
CZ_Mid_Rise = sum([CZ_Bld_Count_4, CZ_Bld_Count_5, CZ_Bld_Count_6, CZ_Bld_Count_7, CZ_Bld_Count_8, CZ_Bld_Count_9])
CZ_High_Rise = sum([CZ_Bld_Count_10, CZ_Bld_Count_11to12, CZ_Bld_Count_13Plus])

print("Czech Republic Low Rise Percentage:", round(CZ_Low_Rise/CZ_Total,3))
print("Czech Republic Mid Rise Percentage:", round(CZ_Mid_Rise/CZ_Total,3))
print("Czech Republic High Rise Percentage:", round(CZ_High_Rise/CZ_Total,3))
# Out:
# Czech Republic 1 Story, LOB = 1: 587985
# Czech Republic 2 Story, LOB = 1: 899482
# Czech Republic 3 Story, LOB = 1: 95883
# Czech Republic 4 Story, LOB = 1: 48004
# Czech Republic 5 Story, LOB = 1: 23355
# Czech Republic 6 Story, LOB = 1: 10192
# Czech Republic 7 Story, LOB = 1: 5716
# Czech Republic 8 Story, LOB = 1: 15259
# Czech Republic 9 Story, LOB = 1: 3216
# Czech Republic 10 Story, LOB = 1: 700
# Czech Republic 11to12 Story, LOB = 1: 2108
# Czech Republic 13Plus Story, LOB = 1: 1552
# Czech Republic 1 Story, LOB = 2: 2885
# Czech Republic 2 Story, LOB = 2: 7504
# Czech Republic 3 Story, LOB = 2: 4012
# Czech Republic 4 Story, LOB = 2: 2543
# Czech Republic 5 Story, LOB = 2: 750
# Czech Republic 6 Story, LOB = 2: 303
# Czech Republic 7 Story, LOB = 2: 285
# Czech Republic 3 Story, LOB = 8: 276
# Czech Republic 9 Story, LOB = 2: 150
# Czech Republic 10 Story, LOB = 2: 49
# Czech Republic 11to12 Story, LOB = 2: 228
# Czech Republic 13Plus Story, LOB = 2: 251
# ...

# %%
#Poland 

#Does not have height distribution - check with Gabby

# %%
#Put Totals into a list/dataframe
#Check w/ Gabby if we need to filter by LOB

#Switzerland
CF_Bld_Count_1 = CF_Height.loc[CF_Height["NumberOfFloors"] == "1Floor"].sum()
CF_Bld_Count_1 = CF_Bld_Count_1["BuildingCount"]

CF_Bld_Count_2 = CF_Height.loc[CF_Height["NumberOfFloors"] == "2Floors"].sum()
CF_Bld_Count_2 = CF_Bld_Count_2["BuildingCount"]

CF_Bld_Count_3 = CF_Height.loc[CF_Height["NumberOfFloors"] == "3Floors"].sum()
CF_Bld_Count_3 = CF_Bld_Count_3["BuildingCount"]

CF_Bld_Count_4 = CF_Height.loc[CF_Height["NumberOfFloors"] == "4Floors"].sum()
CF_Bld_Count_4 = CF_Bld_Count_4["BuildingCount"]

CF_Bld_Count_5 = CF_Height.loc[CF_Height["NumberOfFloors"] == "5Floors"].sum()
CF_Bld_Count_5 = CF_Bld_Count_5["BuildingCount"]

CF_Bld_Count_6 = CF_Height.loc[CF_Height["NumberOfFloors"] == "6Floors"].sum()
CF_Bld_Count_6 = CF_Bld_Count_6["BuildingCount"]

CF_Bld_Count_7 = CF_Height.loc[CF_Height["NumberOfFloors"] == "7Floors"].sum()
CF_Bld_Count_7 = CF_Bld_Count_7["BuildingCount"]

CF_Bld_Count_8 = CF_Height.loc[CF_Height["NumberOfFloors"] == "8Floors"].sum()
CF_Bld_Count_8 = CF_Bld_Count_8["BuildingCount"]

CF_Bld_Count_9 = CF_Height.loc[CF_Height["NumberOfFloors"] == "9Floors"].sum()
CF_Bld_Count_9 = CF_Bld_Count_9["BuildingCount"]

CF_Bld_Count_10Plus = CF_Height.loc[CF_Height["NumberOfFloors"] == "10PlusFloors"].sum()
CF_Bld_Count_10Plus = CF_Bld_Count_10Plus["BuildingCount"]

CF_Total = sum([CF_Bld_Count_1, CF_Bld_Count_2, CF_Bld_Count_3, CF_Bld_Count_4, CF_Bld_Count_5, CF_Bld_Count_6, CF_Bld_Count_7, CF_Bld_Count_8, CF_Bld_Count_9, CF_Bld_Count_10Plus])

CF_Low_Rise = sum([CF_Bld_Count_1, CF_Bld_Count_2, CF_Bld_Count_3])
CF_Mid_Rise = sum([CF_Bld_Count_4, CF_Bld_Count_5, CF_Bld_Count_6, CF_Bld_Count_7, CF_Bld_Count_8, CF_Bld_Count_9])
CF_High_Rise = sum([CF_Bld_Count_10Plus])

CF_Total = sum([CF_Low_Rise, CF_Mid_Rise, CF_High_Rise])


print("Switzerland Low Rise Percentage:", round(CF_Low_Rise/CF_Total,3))
print("Switzerland Mid Rise Percentage:", round(CF_Mid_Rise/CF_Total,3))
print("Switzerland High Rise Percentage:", round(CF_High_Rise/CF_Total,3))
# Out:
# Switzerland Low Rise Percentage: 0.844
# Switzerland Mid Rise Percentage: 0.155
# Switzerland High Rise Percentage: 0.002

# %%
#Austria
AT_Bld_Count_1 = AT_Height["1Floor"].sum()
AT_Bld_Count_2 = AT_Height["2Floors"].sum()
AT_Bld_Count_3 = AT_Height["3Floors"].sum()
AT_Bld_Count_4 = AT_Height["4Floors"].sum()
AT_Bld_Count_5 = AT_Height["5Floors"].sum()
AT_Bld_Count_6to10 = AT_Height["6to10Floors"].sum()
AT_Bld_Count_11Plus = AT_Height["11PlusFloors"].sum()

AT_Low_Rise = sum([AT_Bld_Count_1, AT_Bld_Count_2, AT_Bld_Count_3])
AT_Mid_Rise = sum([AT_Bld_Count_4, AT_Bld_Count_5, AT_Bld_Count_6to10])
AT_High_Rise = AT_Bld_Count_11Plus

AT_Total = sum([AT_Low_Rise, AT_Mid_Rise, AT_High_Rise])

print("Austria Low Rise Percentage:", round(AT_Low_Rise/AT_Total,3))
print("Austria Mid Rise Percentage:", round(AT_Mid_Rise/AT_Total,3))
print("Austria High Rise Percentage:", round(AT_High_Rise/AT_Total,3))
# Out:
# Austria Low Rise Percentage: 0.947
# Austria Mid Rise Percentage: 0.053
# Austria High Rise Percentage: 0.0
